# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage
url = "https://www.srh-university.de/en/programme-finder/types/bachelor/master/mba/certificate/approbation/dba/languages/german/english/both"

# Send a GET request to fetch the HTML content of the page
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the program items
program_items = soup.find_all('div', class_='b_programfinder-results__item')

# Loop through each program item and extract the program name and its link
program_data = []
for item in program_items:
    link_tag = item.find('a', class_='b_programfinder-card__link')
    if link_tag:
        # Extract the program name and link
        program_name = item.find('div', class_='b_programfinder-card__name').get_text(strip=True)
        program_link = link_tag['href']
        full_link = f"https://www.srh-university.de{program_link}"  # Construct the full URL
        program_data.append((program_name, full_link))

# Print the extracted data
for program in program_data:
    print(f"Program Name: {program[0]}")
    print(f"Link: {program[1]}")
    print('-' * 50)
# Out:
# Program Name: International Business Administration
# Link: https://www.srh-university.de/en/bachelor/international-business-administration/b/
# --------------------------------------------------
# Program Name: Advertising & Brand Design
# Link: https://www.srh-university.de/en/bachelor/advertising-brand-design/c/
# --------------------------------------------------
# Program Name: Applied Computer Science
# Link: https://www.srh-university.de/en/master/applied-computer-science/i/
# --------------------------------------------------
# Program Name: Applied Data Science and Analytics
# Link: https://www.srh-university.de/en/master/applied-data-science-and-analytics/i/
# --------------------------------------------------
# Program Name: Applied Mechatronic Systems
# Link: https://www.srh-university.de/en/bachelor/applied-mechatronic-systems/e/
# --------------------------------------------------
# Program Name: Architecture - Design for the Built Environment
# Link: https://www.srh-university.de/en/master/architecture-design-for-the-built-environment/a/
# --------------------------------------------------
# Program Name: Artificial Intelligence
# Link: https://www.srh-university.de/en/master/bls/information-technology-artificial-intelligence/
# --------------------------------------------------
# Program Name: Audio Design
# Link: https://www.srh-university.de/en/bachelor/audio-design/m/
# --------------------------------------------------
# Program Name: Automotive Technology and Management
# Link: https://www.srh-university.de/en/bachelor/international-business-administration-automotive-technology-and-management/b/
# --------------------------------------------------
# Program Name: Big Data and Artificial Intelligence
# Link: https://www.srh-university.de/en/master/computer-science-big-data-artificial-intelligence/i/
# --------------------------------------------------
# Program Name: Blockchain Technology
# Link: https://www.srh-university.de/en/master/information-technology-blockchain-technology/i/
# --------------------------------------------------
# Program Name: Business Analytics
# Link: https://www.srh-university.de/en/master/data-science-business-analytics/i/
# --------------------------------------------------
# Program Name: Business Engineering
# Link: https://www.srh-university.de/en/bachelor/business-engineering/e/
# --------------------------------------------------
# Program Name: Business Psychology
# Link: https://www.srh-university.de/en/bachelor/international-business-administration-business-psychology/b/
# --------------------------------------------------
# Program Name: Computer Science
# Link: https://www.srh-university.de/en/bachelor/computer-science/i/
# --------------------------------------------------
# Program Name: Creative Industries Management
# Link: https://www.srh-university.de/en/bachelor/creative-industries-management/c/
# --------------------------------------------------
# Program Name: Creative Leadership
# Link: https://www.srh-university.de/en/master/international-management-creative-leadership/b/
# --------------------------------------------------
# Program Name: Cyber Security
# Link: https://www.srh-university.de/en/master/computer-science-cyber-security/i/
# --------------------------------------------------
# Program Name: CyberMACS | Applied Cybersecurity
# Link: https://www.srh-university.de/en/master/cybermacs/i/
# --------------------------------------------------
# Program Name: Dance Movement Therapy
# Link: https://www.srh-university.de/en/master/dance-movement-therapy/t/
# --------------------------------------------------
# Program Name: Digital Health
# Link: https://www.srh-university.de/en/master/data-science-digital-health/i/
# --------------------------------------------------
# Program Name: Digital Marketing
# Link: https://www.srh-university.de/en/bachelor/international-business-administration-digital-marketing/b/
# --------------------------------------------------
# Program Name: Digital Supply Chain Management
# Link: https://www.srh-university.de/en/master/digital-supply-chain-management/g/
# --------------------------------------------------
# Program Name: Digital Transformation Management
# Link: https://www.srh-university.de/en/master/digital-transformation-management/b/
# --------------------------------------------------
# Program Name: Digital Transformation Management | berufsbegleitend
# Link: https://www.srh-university.de/en/master/bls/digital-transformation-management-berufsbegleitend/
# --------------------------------------------------
# Program Name: Doctor of Business Administration
# Link: https://www.srh-university.de/en/mba/doctor-of-business-administration/b/
# --------------------------------------------------
# Program Name: Electrical Engineering
# Link: https://www.srh-university.de/en/bachelor/electrical-engineering/e/
# --------------------------------------------------
# Program Name: Entrepreneurship and Intrapreneurship
# Link: https://www.srh-university.de/en/master/international-management-entrepreneurship-and-intrapreneurship/b/
# --------------------------------------------------
# Program Name: Executive MBA General Management
# Link: https://www.srh-university.de/en/mba/executive-mba-general-management/b/
# --------------------------------------------------
# Program Name: Film & Motion Design
# Link: https://www.srh-university.de/en/bachelor/film-motion-design/v/
# --------------------------------------------------
# Program Name: Film, Television and Digital Narratives
# Link: https://www.srh-university.de/en/master/film-television-digital-narratives/v/
# --------------------------------------------------
# Program Name: General Management
# Link: https://www.srh-university.de/en/mba/general-management/b/
# --------------------------------------------------
# Program Name: Global Business and Leadership
# Link: https://www.srh-university.de/en/master/global-business-and-leadership/
# --------------------------------------------------
# Program Name: Global Hospitality Management
# Link: https://www.srh-university.de/en/bachelor/global-hospitality-management/x/
# --------------------------------------------------
# Program Name: Healthcare Management
# Link: https://www.srh-university.de/en/bachelor/international-business-administration-healthcare-management/b/
# --------------------------------------------------
# Program Name: Healthcare Management
# Link: https://www.srh-university.de/en/mba/healthcare-management/b/
# --------------------------------------------------
# Program Name: Healthcare Management
# Link: https://www.srh-university.de/en/bachelor/computer-science-healthcare-management/i/
# --------------------------------------------------
# Program Name: Healthcare Management
# Link: https://www.srh-university.de/en/master/international-business-healthcare-management/b/
# --------------------------------------------------
# Program Name: Hospitality Management and Leadership
# Link: https://www.srh-university.de/en/master/hospitality-management-and-leadership/x/
# --------------------------------------------------
# Program Name: Illustration
# Link: https://www.srh-university.de/en/bachelor/illustration/v/
# --------------------------------------------------
# Program Name: Industry 4.0: Automation, Robotics & 3D Manufacturing
# Link: https://www.srh-university.de/en/master/engineering-sustainable-technology-management-industry-40-automation-robotics-3d-manufacturing/e/
# --------------------------------------------------
# Program Name: Information Technology
# Link: https://www.srh-university.de/en/master/information-technology-information-technology/i/
# --------------------------------------------------
# Program Name: International Business and Engineering
# Link: https://www.srh-university.de/en/master/international-business-and-engineering/e/
# --------------------------------------------------
# Program Name: International Business and Leadership
# Link: https://www.srh-university.de/en/master/bls/international-business-and-leadership/
# --------------------------------------------------
# Program Name: International Management
# Link: https://www.srh-university.de/en/master/international-management/b/
# --------------------------------------------------
# Program Name: Mechanical Engineering
# Link: https://www.srh-university.de/en/bachelor/mechanical-engineering/e/
# --------------------------------------------------
# Program Name: Mobility and Automotive Industry
# Link: https://www.srh-university.de/en/master/engineering-sustainable-technology-management-mobility-automotive-industry/e/
# --------------------------------------------------
# Program Name: Music Production
# Link: https://www.srh-university.de/en/bachelor/music-production/m/
# --------------------------------------------------
# Program Name: Music Therapy
# Link: https://www.srh-university.de/en/master/music-therapy/t/
# --------------------------------------------------
# Program Name: Photography
# Link: https://www.srh-university.de/en/master/photography/v/
# --------------------------------------------------
# Program Name: Photography
# Link: https://www.srh-university.de/en/bachelor/photography/v/
# --------------------------------------------------
# Program Name: Popular Music
# Link: https://www.srh-university.de/en/bachelor/popular-music/m/
# --------------------------------------------------
# Program Name: Renewable Energy, Water and Waste Management
# Link: https://www.srh-university.de/en/master/engineering-international-business-renewable-energy-water-waste-management/e/
# --------------------------------------------------
# Program Name: Smart Building Technologies
# Link: https://www.srh-university.de/en/master/engineering-and-sustainable-technology-management-smart-building-technologies/e/
# --------------------------------------------------
# Program Name: Social Design & Sustainable Innovation
# Link: https://www.srh-university.de/en/master/social-design-sustainable-innovation/v/
# --------------------------------------------------
# Program Name: Strategic Design
# Link: https://www.srh-university.de/en/master/strategic-design/v/
# --------------------------------------------------
# Program Name: Supply Chain Management
# Link: https://www.srh-university.de/en/master/supply-chain-management-english/g/
# --------------------------------------------------
# Program Name: Supply Chain Management
# Link: https://www.srh-university.de/en/bachelor/international-business-administration-supply-management/b/
# --------------------------------------------------
# Program Name: Supply Chain Management | distance-learning
# Link: https://www.srh-university.de/en/master/supply-chain-management-distance-learning/g/
# --------------------------------------------------
# Program Name: Sustainability and Circular Economy Management
# Link: https://www.srh-university.de/en/master/sustainability-and-circular-economy-management/n/
# --------------------------------------------------
# Program Name: Sustainability Management
# Link: https://www.srh-university.de/en/master/international-business-sustainability-management/b/
# --------------------------------------------------
# Program Name: Sustainable Battery Production Engineering | dual
# Link: https://www.srh-university.de/en/master/sustainable-battery-production-engineering-dual/e/
# --------------------------------------------------
# Program Name: Sustainable Supply Chain Management
# Link: https://www.srh-university.de/en/master/sustainable-supply-chain-management/g/
# --------------------------------------------------
# Program Name: User Experience Design and Content Creation
# Link: https://www.srh-university.de/en/bachelor/user-experience-design-content-creation/d/
# --------------------------------------------------
# Program Name: Water Technology
# Link: https://www.srh-university.de/en/master/water-technology/e/
# --------------------------------------------------
# Program Name: Web Development
# Link: https://www.srh-university.de/en/bachelor/web-development/d/
# --------------------------------------------------
# Program Name: Web Development | dual
# Link: https://www.srh-university.de/en/bachelor/web-development-dual/d/
# --------------------------------------------------
# Program Name: Change Management Executive Programme
# Link: https://www.srh-university.de/en/short-courses/change-management-executive-programme/
# --------------------------------------------------
# Program Name: International Wind Industry Training
# Link: https://www.srh-university.de/en/short-courses/international-wind-industry-training/e/
# --------------------------------------------------
# Program Name: Solar Summer Team-up!
# Link: https://www.srh-university.de/en/short-courses/solar-summer-team-up/e/
# --------------------------------------------------
# Program Name: Solar Winter School
# Link: https://www.srh-university.de/en/short-courses/solar-winter-school/e/
# --------------------------------------------------

# %%
len(program_data)
# Out:
# 71

# %%
import pandas as pd 

df=pd.DataFrame(program_data,columns=['Program Name','Link'])

# %%
df.nunique()
# Out:
# Program Name    71
# Link            71
# dtype: int64

# %%
df['Program Name'] = df.groupby('Program Name').cumcount().astype(str).radd(df['Program Name'] + '_').str.rstrip('_0')

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page
url = 'https://www.srh-university.de/en/master/applied-computer-science/i/'

# Send a request to fetch the page content
response = requests.get(url)

# Parse the page content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the main content div with class 'wrapper'
main_div = soup.find('main', class_='b_main')
if main_div:
    # Remove any header or footer elements inside the main div (if they exist)
    for tag in main_div.find_all(['header', 'footer']):
        tag.decompose()  # Remove these tags and their content

    # Extract the text from the cleaned main div
    text = main_div.get_text(separator='\n', strip=True)
    print(text)

else:
    print("Div with class 'wrapper' not found.")
# Out:
# Master
# Master of Science | Multiple locations
# How can computer science find applications in business and research? Enhance your knowledge with our Master's in Applied Computer Science and embark on a career with the employer of your choice or pursue a doctorate.
# Request information
# Apply now
# Apply
# Key facts
# Programme content
# Career
# Smart financing
# All Facts at a glance
# Degree:
# Master of Science (M.Sc.)
# Start:
# 1sr april; 1st october
# Model:
# full time
# Language:
# English
# ECTS:
# 120
# Info:
# accredited
# Duration:
# 4 semester/2 years
# Location:
# Heidelberg,
#
# 										Stuttgart,
#
# 										Fuerth
# Costs:
# from €750 per month
#
# 										-
# Show costs split
# You need sound and up-to-date knowledge beyond your first academic degree to apply computer science in business and research. In our Master's programme in Applied Computer Science, we provide you with this knowledge and the relevant skills you need for your professional career - at a high level and with a practical orientation. If you aim for a computer science doctorate, this degree is a prerequisite.
# In the first semester, you choose one of the three specialisations, 'Business Computing', 'Mobile Computing' or 'Usability Engineering and UX Design'. You will take elective modules from your chosen specialisation in the first three semesters.
# With a degree in Applied Computer Science, you have the best chances of finding an exciting and highly-paid position in the software and IT industry. Graduates from previous years have worked in large companies such as ABB, Airbus or Accenture, at Adidas, Audi, Bosch, BMW, BASF, Deloitte, Deutsche Börse, DKFZ, Triumph, PWC, SAP and Verivox, as well as in successful small and medium-sized companies. Our programme also qualifies you for public sector positions, research work and a doctorate.
# Possible areas of work:
# Software engineer and architect
# Full-stack software developer
# System analyst
# System designer
# IT project manager
# IT consultant
# previous slide
# next slide
# 02.12.2024
# Join us for a live online Q&A session with our study advisors. We will answer your questions about study programmes, provide academic guidance, and answer general enquiries.
# Anmeldung/Registration
# 04.12.2024
# Meet our study advisors online and learn how our application system works and which documents and proofs you need to provide.
# Anmeldung/Registration
# 11.12.2024
# Join us for the last workshop of the STREAM project, where we'll show how we've engaged local communities in Germany, Austria, Hungary and Serbia to raise awareness about water pollution and the Danube's unique soundscape.
# SRH University Campus Heidelberg
# 11.12.2024
# Event in German and English | Learn more about funding opportunities for EU and non-EU students.
# Anmeldung/Registration
# 17.12.2024
# Join us for an info session on Masters in Applied Data Science and Analytics! Discover how our program equips you with hands-on skills to tackle real-world data challenges and advance your career.
# Online via Teams
# 18.12.2024
# Discover the benefits of studying in Germany from the comfort of your own home in our upcoming webinar!
# Registration
# 21.01.2025
# Join us for an info session on Masters in Applied Data Science and Analytics! Discover how our program equips you with hands-on skills to tackle real-world data challenges and advance your career.
# Online via Teams
# Your path to the future
# Start your application now
# The Master's programme in Applied Computer Science provides comprehensive knowledge in software development, data analysis, and modern information systems. Students learn programming languages, algorithms, and data structures to develop innovative solutions for complex problems.
# Hands-on modules such as software engineering and databases and such issues as artificial intelligence and cybersecurity promote the development of future-oriented skills. Business analytics and data science are also covered to make data-based decisions.
# Agile methods train students in flexible project work and team communication. In your Master's thesis, you will apply the acquired knowledge in a project.
# We will be happy to send you further information, including the complete curriculum.
# Order your information material
# Our CORE Principle
# Today, soft and social skills are crucial in addition to hard skills and expertise. That's why
# SRH University
# 's innovative, successful, and award-winning
# CORE principle
# promotes independent and active learning so that you can apply your knowledge directly to projects and your future career—for a clear competitive advantage.
# Learn more about CORE
# By playing this video, the provider may store personal data such as your IP address.
# What I admire most about SRH University and its staff and lecturers is the freedom and support to pursue your own goals and dreams.
# Vaibhav Sakharkar, Alumnus Applied Computer Science (M.Sc.)
# previous slide
# next slide
# Head of Study Programme
# Professor
# Professor
# Chief Innovation Officer
# Lecturer
# Lecturer
# Lecturer for Special Tasks
# Research Associate
# As a state-recognised private university, SRH University is financed by tuition fees. The fees go towards equipping our campuses, providing services for our students, and ensuring quality assurance. This way, we ensure you receive the best possible education under optimal study conditions.
# Tuition fees
# Citizenship | EU/EEA, including Western Balkans, Switzerland and Ukraine: €750 / month
# Citizenship | non-EU/EEA: €6,450 / semester
# The monthly/semester tuition fees remain the same for the entire duration of the study programme. A one-off enrolment fee of €750 (EU/EEA) or €1000 (non-EU/EEA) is to be paid once.
# Except for any placement, aptitude or equivalency tests, no separate examination fees or similar are charged, not even for repeat examinations. So, you'll have maximum cost transparency during your studies.
# Goal-oriented studies require good organisational skills and solid financial planning on how to pay rent, living costs, and tuition fees. Various financing options, such as educational loans or scholarship programmes, are available for students.
# We have summarised all financing options for you.
# About your financing options
# You can apply at any time via our
# online portal
# . We will then check your application documents and invite you to a personal interview.
# To apply for the
# Master's programme in Applied Data Science and Analytics,
# you will need to provide
# Bachelor's degree in
# Computer Science, Applied Computer Science, Information Management, IT, Software Development, Virtual Realities or similar area of studies
# Good knowledge of object-oriented programming languages (Java/C++/Python, etc.) and databases (MySQL, PostgreSQL, Oracle, etc.)
# Secondary School Certificate
# Proof of English language proficiency
# Curriculum Vitae with a current passport photo
# Copy of your identity card or passport
# More information about the admission requirements
# Apply now
# We look forward to welcoming you to SRH University. This is what our application process looks like:
# You submit your online application via the SRH application portal
# If you meet the admission requirements, we will invite you to a personal/phone interview
# If the interview is successful, you will receive an acceptance letter and the study contract
# You sign the study contract and send it back to us
# You pay the enrolment fee
# You will receive your letter of admission
# You take part in our Startklar days and then you are good to go!
# Do you still have questions?
# Share:

# %%
# Search for the phrase "200 and 300-level" in the content
search_phrase = "Alle Fakten auf einen Blick"

# Check if the phrase exists in the file content
if search_phrase in text:
    print(f"The phrase '{search_phrase}' was found in the file.")
else:
    print(f"The phrase '{search_phrase}' was NOT found in the file.")
# Out:
# The phrase 'Alle Fakten auf einen Blick' was NOT found in the file.

# %%
df.nunique()
# Out:
# Program Name    71
# Link            71
# dtype: int64

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# Create a directory to store the text files
os.makedirs("srh_university_update/", exist_ok=True)

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    degree_name = row['Program Name']
    url = row['Link']

    # Send a GET request to fetch the HTML content of the webpage
    response = requests.get(url)

    if response.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')

         # Find the div with specific id and class
        body_container =  soup.find('main', class_='b_main')

        if body_container:
            # Remove any header or footer elements inside the main div (if they exist)
            for tag in body_container.find_all(['header', 'footer']):
                tag.decompose()  # Remove these tags and their content
            # Extract all text from the main content
            text_content = body_container.get_text(separator='\n', strip=True)

            # Create a valid filename by replacing invalid characters
            filename = f"srh_university_update/{degree_name.replace('/', '_').replace(' ', '_').replace('|','_')}.txt"

            # Save the link and text content to the file
            with open(filename, "w", encoding="utf-8") as file:
                # Write the link at the top
                file.write(f"Link: {url}\n\n")
                # Write the extracted content below the link
                file.write(text_content)

            print(f"Content successfully saved to '{filename}'.")
        else:
            print(f"Main content not found for {degree_name}.")
    else:
        print(f"Failed to retrieve the webpage for {degree_name}. Status code: {response.status_code}")
# Out:
# Content successfully saved to 'srh_university_update/International_Business_Administration.txt'.
# Content successfully saved to 'srh_university_update/Advertising_&_Brand_Design.txt'.
# Content successfully saved to 'srh_university_update/Applied_Computer_Science.txt'.
# Content successfully saved to 'srh_university_update/Applied_Data_Science_and_Analytics.txt'.
# Content successfully saved to 'srh_university_update/Applied_Mechatronic_Systems.txt'.
# Content successfully saved to 'srh_university_update/Architecture_-_Design_for_the_Built_Environment.txt'.
# Content successfully saved to 'srh_university_update/Artificial_Intelligence.txt'.
# Content successfully saved to 'srh_university_update/Audio_Design.txt'.
# Content successfully saved to 'srh_university_update/Automotive_Technology_and_Management.txt'.
# Content successfully saved to 'srh_university_update/Big_Data_and_Artificial_Intelligence.txt'.
# Content successfully saved to 'srh_university_update/Blockchain_Technology.txt'.
# Content successfully saved to 'srh_university_update/Business_Analytics.txt'.
# Content successfully saved to 'srh_university_update/Business_Engineering.txt'.
# Content successfully saved to 'srh_university_update/Business_Psychology.txt'.
# Content successfully saved to 'srh_university_update/Computer_Science.txt'.
# Content successfully saved to 'srh_university_update/Creative_Industries_Management.txt'.
# Content successfully saved to 'srh_university_update/Creative_Leadership.txt'.
# Content successfully saved to 'srh_university_update/Cyber_Security.txt'.
# Content successfully saved to 'srh_university_update/CyberMACS___Applied_Cybersecurity.txt'.
# Content successfully saved to 'srh_university_update/Dance_Movement_Therapy.txt'.
# Content successfully saved to 'srh_university_update/Digital_Health.txt'.
# Content successfully saved to 'srh_university_update/Digital_Marketing.txt'.
# Content successfully saved to 'srh_university_update/Digital_Supply_Chain_Management.txt'.
# Content successfully saved to 'srh_university_update/Digital_Transformation_Management.txt'.
# Content successfully saved to 'srh_university_update/Digital_Transformation_Management___berufsbegleitend.txt'.
# Content successfully saved to 'srh_university_update/Doctor_of_Business_Administration.txt'.
# Content successfully saved to 'srh_university_update/Electrical_Engineering.txt'.
# Content successfully saved to 'srh_university_update/Entrepreneurship_and_Intrapreneurship.txt'.
# Content successfully saved to 'srh_university_update/Executive_MBA_General_Management.txt'.
# Content successfully saved to 'srh_university_update/Film_&_Motion_Design.txt'.
# Content successfully saved to 'srh_university_update/Film,_Television_and_Digital_Narratives.txt'.
# Content successfully saved to 'srh_university_update/General_Management.txt'.
# Content successfully saved to 'srh_university_update/Global_Business_and_Leadership.txt'.
# Content successfully saved to 'srh_university_update/Global_Hospitality_Management.txt'.
# Content successfully saved to 'srh_university_update/Healthcare_Management.txt'.
# Content successfully saved to 'srh_university_update/Healthcare_Management_1.txt'.
# Content successfully saved to 'srh_university_update/Healthcare_Management_2.txt'.
# Content successfully saved to 'srh_university_update/Healthcare_Management_3.txt'.
# Content successfully saved to 'srh_university_update/Hospitality_Management_and_Leadership.txt'.
# Content successfully saved to 'srh_university_update/Illustration.txt'.
# Content successfully saved to 'srh_university_update/Industry_4.0:_Automation,_Robotics_&_3D_Manufacturing.txt'.
# Content successfully saved to 'srh_university_update/Information_Technology.txt'.
# Content successfully saved to 'srh_university_update/International_Business_and_Engineering.txt'.
# Content successfully saved to 'srh_university_update/International_Business_and_Leadership.txt'.
# Content successfully saved to 'srh_university_update/International_Management.txt'.
# Content successfully saved to 'srh_university_update/Mechanical_Engineering.txt'.
# Content successfully saved to 'srh_university_update/Mobility_and_Automotive_Industry.txt'.
# Content successfully saved to 'srh_university_update/Music_Production.txt'.
# Content successfully saved to 'srh_university_update/Music_Therapy.txt'.
# Content successfully saved to 'srh_university_update/Photography.txt'.
# Content successfully saved to 'srh_university_update/Photography_1.txt'.
# Content successfully saved to 'srh_university_update/Popular_Music.txt'.
# Content successfully saved to 'srh_university_update/Renewable_Energy,_Water_and_Waste_Management.txt'.
# Content successfully saved to 'srh_university_update/Smart_Building_Technologies.txt'.
# Content successfully saved to 'srh_university_update/Social_Design_&_Sustainable_Innovation.txt'.
# Content successfully saved to 'srh_university_update/Strategic_Design.txt'.
# Content successfully saved to 'srh_university_update/Supply_Chain_Management.txt'.
# Content successfully saved to 'srh_university_update/Supply_Chain_Management_1.txt'.
# Content successfully saved to 'srh_university_update/Supply_Chain_Management___distance-learning.txt'.
# Content successfully saved to 'srh_university_update/Sustainability_and_Circular_Economy_Management.txt'.
# Content successfully saved to 'srh_university_update/Sustainability_Management.txt'.
# Content successfully saved to 'srh_university_update/Sustainable_Battery_Production_Engineering___dual.txt'.
# Content successfully saved to 'srh_university_update/Sustainable_Supply_Chain_Management.txt'.
# Content successfully saved to 'srh_university_update/User_Experience_Design_and_Content_Creation.txt'.
# Content successfully saved to 'srh_university_update/Water_Technology.txt'.
# Content successfully saved to 'srh_university_update/Web_Development.txt'.
# Content successfully saved to 'srh_university_update/Web_Development___dual.txt'.
# Content successfully saved to 'srh_university_update/Change_Management_Executive_Programme.txt'.
# Content successfully saved to 'srh_university_update/International_Wind_Industry_Training.txt'.
# Content successfully saved to 'srh_university_update/Solar_Summer_Team-up!.txt'.
# Content successfully saved to 'srh_university_update/Solar_Winter_School.txt'.

# %%
df=df.iloc[28:]

# %%
df=df.iloc[147:]

# %%
len(df)
# Out:
# 180
